# %%
with open("./data/wiki_phrases.txt", "r") as f:
    wiki_words = set()
    for line in f.readlines():
        wiki_words.add(line[:-1])

# %%
wiki_words
# Out:
# {'abstract interpretation',
#  'access control',
#  'adaptable robotics',
#  'adaptive clothing',
#  'adaptive web design',
#  'aerial photography',
#  'affective computing',
#  'agile software development',
#  'algebraic graph theory',
#  'algorave',
#  'algorithmic art',
#  'algorithmic information theory',
#  'algorithmic trading',
#  'algorithms',
#  'ambient intelligence',
#  'amiga',
#  'amines',
#  'analog computers',
#  'analysis of algorithms',
#  'animal identification',
#  'anonymity',
#  'anonymous social media',
#  'anthropometry',
#  'antivirus software',
#  'approximation theory',
#  'architecture description language',
#  'artificial intelligence',
#  'artificial life',
#  'artificial neural networks',
#  'as a service',
#  'assistive technology',
#  'atari st',
#  'audio electronics',
#  'audio mixing',
#  'authentication',
#  'automated reasoning',
#  'automated theorem proving',
#  'automattic',
#  'avionics',
#  'backup',
#  'backup software',
# ...

# %%
with open("./outputs/prdualrank_result_phrases.txt", "r") as f:
    prdualrank_words = set()
    for line in f.readlines():
        prdualrank_words.add(line[:-1])

# %%
prdualrank_words
# Out:
# {'abstractive sentence',
#  'aco techniques',
#  'active learning',
#  'adversarial examples',
#  'adversarial nets',
#  'adversarial networks',
#  'adversarial training',
#  'anatomical structures',
#  'arbitrary orientations',
#  'artificial intelligence',
#  'associative memory',
#  'automatic speech',
#  'back propagation',
#  'basic units',
#  'bayesian methods',
#  'bidirectional lstm',
#  'big data',
#  'black box',
#  'central importance',
#  'commercial advertisements',
#  'commercial speech',
#  'complex behaviors',
#  'complex tasks',
#  'compositional models',
#  'contrastive biclusters',
#  'convolutional autoencoder',
#  'convolutional autoencoders',
#  'convolutional feature',
#  'convolutional filters',
#  'convolutional networks',
#  'coral correlation',
#  'deep learning',
#  'deep nets',
#  'deep networks',
#  'deep reinforcement',
#  'deterministic policy',
#  'different sequence',
#  'different tasks',
#  'different types',
#  'discrete actions',
# ...

# %%
with open("./outputs/autophrase_result_phrases.txt", "r") as f:
    autophrase_words = set(f.readlines())

# %%
def get_accuracy(test_set, base_set):
    acc = 0.0
    acc = ((len(test_set.intersection(base_set))/len(base_set)) * 100)
    return acc

# %%
prdr_acc = get_accuracy(prdualrank_words, wiki_words)
# ap_acc = get_accuracy(autophrase_words, wiki_words)

# %%
print("PRDR Accuracy is: " + str(prdr_acc))
# print("Ap Accuracy is: " + str(ap_acc))
# Out:
# PRDR Accuracy is: 1.1661807580174928

# %%
prdualrank_words.intersection(wiki_words)
# Out:
# {'artificial intelligence',
#  'deep learning',
#  'evolutionary algorithms',
#  'machine translation',
#  'medical imaging',
#  'structured prediction',
#  'supervised learning',
#  'unsupervised learning'}
